# %% [markdown]
# <a href="https://colab.research.google.com/github/bishnujha/bishnujha/blob/main/YoutubeVideoSummarizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install youtube_transcript_api

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# %%
def get_video_id(url_link):
  return url_link.split("watch?v=")[-1]

# %%
video=input("Enter the video link: ")

# %%
video_id=get_video_id(video)

# %%
video_id
# Out:
# 'WUvTyaaNkzM&list=PLZHQObOWTQDMsr9K-rj53DwVRMYO3t5Yr'

# %%
transcript = YouTubeTranscriptApi.get_transcript(video_id)

# %%
transcript
# Out:
# [{'text': 'Hey everyone, Grant here.', 'start': 14.98, 'duration': 1.48},
#  {'text': 'This is the first video in a series on the essence of calculus,',
#   'start': 16.82,
#   'duration': 3.008},
#  {'text': "and I'll be publishing the following videos once per day for the next 10 days.",
#   'start': 19.828,
#   'duration': 3.772},
#  {'text': 'The goal here, as the name suggests, is to really get',
#   'start': 24.3,
#   'duration': 2.611},
#  {'text': 'the heart of the subject out in one binge-watchable set.',
#   'start': 26.911,
#   'duration': 2.809},
#  {'text': "But with a topic that's as broad as calculus, there's a lot of things that can mean,",
#   'start': 30.32,
#   'duration': 3.859},
#  {'text': "so here's what I have in mind specifically.",
#   'start': 34.179,
#   'duration': 2.021},
#  {'text': 'Calculus has a lot of rules and formulas which',
#   'start': 36.94,
#   'duration': 2.473},
#  {'text': 'are often presented as things to be memorized.',
#   'start': 39.413,
#   'duration': 2.527},
#  {'text': 'Lots of derivative formulas, the product rule, the chain rule,',
#   'start': 42.48,
#   'duration': 3.274},
#  {'text': 'implicit differentiation, the fact that integrals and derivatives are opposite,',
#   'start': 45.754,
#   'duration': 4.224},
#  {'text': 'Taylor series, just a lot of things like that.',
#   'start': 49.978,
#   'duration': 2.482},
#  {'text': 'And my goal is for you to come away feeling like',
#   'start': 52.96,
#   'duration': 2.173},
#  {'text': 'you could have invented calculus yourself.',
#   'start': 55.133,
#   'duration': 1.947},
#  {'text': 'That is, cover all those core ideas, but in a way that makes clear where they',
#   'start': 57.64,
#   'duration': 3.998},
#  {'text': 'actually come from, and what they really mean, using an all-around visual approach.',
#   'start': 61.638,
#   'duration': 4.362},
#  {'text': 'Inventing math is no joke, and there is a difference between being',
#   'start': 66.92,
#   'duration': 3.507},
#  {'text': "told why something's true, and actually generating it from scratch.",
#   'start': 70.427,
#   'duration': 3.613},
#  {'text': 'But at all points, I want you to think to yourself, if you were an early mathematician,',
#   'start': 74.68,
#   'duration': 4.411},
#  {'text': 'pondering these ideas and drawing out the right diagrams,',
#   'start': 79.091,
#   'duration': 2.941},
#  {'text': 'does it feel reasonable that you could have stumbled across these truths yourself?',
#   'start': 82.032,
#   'duration': 4.208},
#  {'text': 'In this initial video, I want to show how you might stumble into the core ideas of',
#   'start': 86.82,
#   'duration': 4.749},
#  {'text': 'calculus by thinking very deeply about one specific bit of geometry,',
#   'start': 91.569,
#   'duration': 3.997},
#  {'text': 'the area of a circle.', 'start': 95.566, 'duration': 1.274},
#  {'text': 'Maybe you know that this is pi times its radius squared, but why?',
#   'start': 97.78,
#   'duration': 3.26},
#  {'text': 'Is there a nice way to think about where this formula comes from?',
#   'start': 101.58,
#   'duration': 2.88},
#  {'text': 'Well, contemplating this problem and leaving yourself open to exploring the',
#   'start': 105.42,
#   'duration': 3.906},
#  {'text': 'interesting thoughts that come about can actually lead you to a glimpse of three',
#   'start': 109.326,
#   'duration': 4.219},
#  {'text': "big ideas in calculus, integrals, derivatives, and the fact that they're opposites.",
#   'start': 113.545,
#   'duration': 4.375},
#  {'text': "But the story starts more simply, just you and a circle, let's say with radius 3.",
#   'start': 119.84,
#   'duration': 5.0},
#  {'text': "You're trying to figure out its area, and after going through a lot of",
#   'start': 125.7,
#   'duration': 3.682},
#  {'text': 'paper trying different ways to chop up and rearrange the pieces of that area,',
#   'start': 129.382,
#   'duration': 4.103},
#  {'text': 'many of which might lead to their own interesting observations,',
#   'start': 133.485,
#   'duration': 3.367},
#  {'text': 'maybe you try out the idea of slicing up the circle into many concentric rings.',
#   'start': 136.852,
#   'duration': 4.208},
#  {'text': 'This should seem promising because it respects the symmetry of the circle,',
#   'start': 142.0,
#   'duration': 3.807},
#  {'text': 'and math has a tendency to reward you when you respect its symmetries.',
#   'start': 145.807,
#   'duration': 3.653},
#  {'text': "Let's take one of those rings, which has some inner radius r that's between 0 and 3.",
#   'start': 150.36,
#   'duration': 4.7},
#  {'text': 'If we can find a nice expression for the area of each ring like this one,',
#   'start': 156.22,
#   'duration': 3.702},
#  {'text': 'and if we have a nice way to add them all up,',
#   'start': 159.922,
#   'duration': 2.333},
#  {'text': "it might lead us to an understanding of the full circle's area.",
#   'start': 162.255,
#   'duration': 3.245},
#  {'text': 'Maybe you start by imagining straightening out this ring.',
#   'start': 166.42,
#   'duration': 2.7},
#  {'text': 'And you could try thinking through exactly what this new shape is and what its',
#   'start': 170.8,
#   'duration': 4.19},
#  {'text': "area should be, but for simplicity, let's just approximate it as a rectangle.",
#   'start': 174.99,
#   'duration': 4.19},
#  {'text': 'The width of that rectangle is the circumference of the original ring,',
#   'start': 180.18,
#   'duration': 3.682},
#  {'text': 'which is 2 pi times r, right?',
#   'start': 183.862,
#   'duration': 1.578},
#  {'text': "I mean, that's essentially the definition of pi.",
#   'start': 185.86,
#   'duration': 2.2},
#  {'text': 'And its thickness?', 'start': 188.68, 'duration': 0.7},
#  {'text': 'Well, that depends on how finely you chopped up the circle in the first place,',
#   'start': 190.2,
#   'duration': 3.951},
#  {'text': 'which was kind of arbitrary.', 'start': 194.151, 'duration': 1.469},
#  {'text': 'In the spirit of using what will come to be standard calculus notation,',
#   'start': 196.34,
#   'duration': 3.755},
#  {'text': "let's call that thickness dr for a tiny difference in the radius from one ring to",
#   'start': 200.095,
#   'duration': 4.336},
#  {'text': 'the next.', 'start': 204.431, 'duration': 0.529},
#  {'text': 'Maybe you think of it as something like 0.1.',
#   'start': 205.48,
#   'duration': 2.4},
#  {'text': 'So approximating this unwrapped ring as a thin rectangle,',
#   'start': 208.98,
#   'duration': 3.869},
#  {'text': 'its area is 2 pi times r, the radius, times dr, the little thickness.',
#   'start': 212.849,
#   'duration': 4.751},
#  {'text': "And even though that's not perfect, for smaller and smaller choices of dr,",
#   'start': 218.6,
#   'duration': 3.837},
#  {'text': 'this is actually going to be a better and better approximation for that area,',
#   'start': 222.437,
#   'duration': 4.044},
#  {'text': 'since the top and the bottom sides of this shape are going to get closer and closer to',
#   'start': 226.481,
#   'duration': 4.512},
#  {'text': 'being exactly the same length.',
#   'start': 230.993,
#   'duration': 1.607},
#  {'text': "So let's just move forward with this approximation,",
#   'start': 233.54,
#   'duration': 2.393},
#  {'text': "keeping in the back of our minds that it's slightly wrong,",
#   'start': 235.933,
#   'duration': 2.768},
#  {'text': "but it's going to become more accurate for smaller and smaller choices of dr.",
#   'start': 238.701,
#   'duration': 3.659},
#  {'text': 'That is, if we slice up the circle into thinner and thinner rings.',
#   'start': 243.22,
#   'duration': 3.18},
#  {'text': "So just to sum up where we are, you've broken up the area of the circle into",
#   'start': 247.7,
#   'duration': 4.683},
#  {'text': "all of these rings, and you're approximating the area of each one of those as",
#   'start': 252.383,
#   'duration': 4.807},
#  {'text': '2 pi times its radius times dr, where the specific value for that inner radius',
#   'start': 257.19,
#   'duration': 4.868},
#  {'text': 'ranges from 0 for the smallest ring up to just under 3 for the biggest ring,',
#   'start': 262.058,
#   'duration': 4.746},
#  {'text': 'spaced out by whatever the thickness is that you choose for dr, something like 0.1.',
#   'start': 266.804,
#   'duration': 5.176},
#  {'text': 'And notice that the spacing between the values here corresponds to the',
#   'start': 273.14,
#   'duration': 3.834},
#  {'text': 'thickness dr of each ring, the difference in radius from one ring to the next.',
#   'start': 276.974,
#   'duration': 4.326},
#  {'text': 'In fact, a nice way to think about the rectangles approximating each',
#   'start': 282.26,
#   'duration': 3.752},
#  {'text': "ring's area is to fit them all upright side by side along this axis.",
#   'start': 286.012,
#   'duration': 3.808},
#  {'text': 'Each one has a thickness dr, which is why they fit so snugly right there together,',
#   'start': 290.66,
#   'duration': 5.16},
#  {'text': 'and the height of any one of these rectangles sitting above some specific value of r,',
#   'start': 295.82,
#   'duration': 5.411},
#  {'text': 'like 0.6, is exactly 2 pi times that value.',
#   'start': 301.231,
#   'duration': 2.769},
#  {'text': "That's the circumference of the corresponding ring that this rectangle approximates.",
#   'start': 304.64,
#   'duration': 4.32},
#  {'text': 'Pictures like this 2 pi r can get tall for the screen,',
#   'start': 309.56,
#   'duration': 2.989},
#  {'text': "I mean 2 times pi times 3 is around 19, so let's just throw up a y axis that's",
#   'start': 312.549,
#   'duration': 4.373},
#  {'text': 'scaled a little differently so that we can actually fit all of these rectangles',
#   'start': 316.922,
#   'duration': 4.428},
#  {'text': 'on the screen.', 'start': 321.35, 'duration': 0.83},
#  {'text': 'A nice way to think about this setup is to draw the graph of 2 pi r,',
#   'start': 323.26,
#   'duration': 3.681},
#  {'text': 'which is a straight line that has a slope 2 pi.',
#   'start': 326.941,
#   'duration': 2.599},
#  {'text': 'Each of these rectangles extends up to the point where it just barely touches that graph.',
#   'start': 330.1,
#   'duration': 4.7},
#  {'text': "Again, we're being approximate here.",
#   'start': 336.0,
#   'duration': 1.46},
#  {'text': 'Each of these rectangles only approximates the',
#   'start': 337.9,
#   'duration': 2.114},
#  {'text': 'area of the corresponding ring from the circle.',
#   'start': 340.014,
#   'duration': 2.206},
#  {'text': 'But remember, that approximation, 2 pi r times dr,',
#   'start': 342.94,
#   'duration': 3.303},
#  {'text': 'gets less and less wrong as the size of dr gets smaller and smaller.',
#   'start': 346.243,
#   'duration': 4.557},
#  {'text': "And this has a very beautiful meaning when we're",
#   'start': 351.8,
#   'duration': 2.167},
#  {'text': 'looking at the sum of the areas of all those rectangles.',
#   'start': 353.967,
#   'duration': 2.573},
#  {'text': 'For smaller and smaller choices of dr, you might at first',
#   'start': 357.08,
#   'duration': 2.978},
#  {'text': 'think that turns the problem into a monstrously large sum.',
#   'start': 360.058,
#   'duration': 3.082},
#  {'text': "I mean, there's many many rectangles to consider,",
#   'start': 363.6,
#   'duration': 1.96},
#  {'text': 'and the decimal precision of each one of their areas is going to be an',
#   'start': 365.56,
#   'duration': 2.84},
#  {'text': 'absolute nightmare.', 'start': 368.4, 'duration': 0.8},
#  {'text': 'But notice, all of their areas in aggregate just looks like the area under a graph.',
#   'start': 370.06,
#   'duration': 5.24},
#  {'text': 'And that portion under the graph is just a triangle,',
#   'start': 375.98,
#   'duration': 3.385},
#  {'text': "a triangle with a base of 3 and a height that's 2 pi times 3.",
#   'start': 379.365,
#   'duration': 4.035},
#  {'text': 'So its area, 1 half base times height, works out to be exactly pi times 3 squared.',
#   'start': 384.14,
#   'duration': 6.36},
#  {'text': 'Or if the radius of our original circle was some other value,',
#   'start': 391.36,
#   'duration': 3.774},
#  {'text': 'capital R, that area comes out to be pi times r squared.',
#   'start': 395.134,
#   'duration': 3.526},
#  {'text': "And that's the formula for the area of a circle.",
#   'start': 399.38,
#   'duration': 2.08},
#  {'text': "It doesn't matter who you are or what you typically think of math,",
#   'start': 402.32,
#   'duration': 3.092},
#  {'text': 'that right there is a beautiful argument.',
#   'start': 405.412,
#   'duration': 1.968},
#  {'text': 'But if you want to think like a mathematician here,',
#   'start': 410.18,
#   'duration': 2.638},
#  {'text': "you don't just care about finding the answer,",
#   'start': 412.818,
#   'duration': 2.378},
#  {'text': 'you care about developing general problem-solving tools and techniques.',
#   'start': 415.196,
#   'duration': 3.724},
#  {'text': 'So take a moment to meditate on what exactly just happened and why it worked,',
#   'start': 419.68,
#   'duration': 4.086},
#  {'text': 'because the way we transitioned from something approximate to something',
#   'start': 423.766,
#   'duration': 3.821},
#  {'text': 'precise is actually pretty subtle and cuts deep to what calculus is all about.',
#   'start': 427.587,
#   'duration': 4.193},
#  {'text': 'You had this problem that could be approximated with the sum of many small numbers,',
#   'start': 433.82,
#   'duration': 5.089},
#  {'text': 'each of which looked like 2 pi r times dr, for values of r ranging between 0 and 3.',
#   'start': 438.909,
#   'duration': 5.151},
#  {'text': 'Remember, the small number dr here represents our choice for the thickness of each ring,',
#   'start': 446.6,
#   'duration': 5.347},
#  {'text': 'for example 0.1.', 'start': 451.947, 'duration': 1.033},
#  {'text': 'And there are two important things to note here.',
#   'start': 453.52,
#   'duration': 2.12},
#  {'text': "First of all, not only is dr a factor in the quantities we're adding up,",
#   'start': 456.08,
#   'duration': 4.56},
#  {'text': '2 pi r times dr, it also gives the spacing between the different values of r.',
#   'start': 460.64,
#   'duration': 4.94},
#  {'text': 'And secondly, the smaller our choice for dr, the better the approximation.',
#   'start': 466.24,
#   'duration': 4.28},
#  {'text': 'Adding all of those numbers could be seen in a different,',
#   'start': 472.2,
#   'duration': 3.003},
#  {'text': 'pretty clever way as adding the areas of many thin rectangles',
#   'start': 475.203,
#   'duration': 3.266},
#  {'text': 'sitting underneath a graph, the graph of the function 2 pi r in this case.',
#   'start': 478.469,
#   'duration': 3.951},
#  {'text': 'Then, and this is key, by considering smaller and smaller choices for dr,',
#   'start': 482.94,
#   'duration': 4.486},
#  {'text': 'corresponding to better and better approximations of the original problem, the sum,',
#   'start': 487.426,
#   'duration': 5.162},
#  {'text': 'thought of as the aggregate area of those rectangles,',
#   'start': 492.588,
#   'duration': 3.318},
#  {'text': 'approaches the area under the graph.',
#   'start': 495.906,
#   'duration': 2.274},
#  {'text': 'And because of that, you can conclude that the answer to the original question,',
#   'start': 499.0,
#   'duration': 4.477},
#  {'text': 'in full unapproximated precision, is exactly the same as the area underneath this graph.',
#   'start': 503.477,
#   'duration': 5.043},
#  {'text': 'A lot of other hard problems in math and science can be broken down and',
#   'start': 510.86,
#   'duration': 4.401},
#  {'text': 'approximated as the sum of many small quantities,',
#   'start': 515.261,
#   'duration': 3.1},
#  {'text': 'like figuring out how far a car has traveled based on its velocity at each point in time.',
#   'start': 518.361,
#   'duration': 5.579},
#  {'text': 'In a case like that, you might range through many different points in time,',
#   'start': 524.76,
#   'duration': 4.01},
#  {'text': 'and at each one multiply the velocity at that time times a tiny change in time, dt,',
#   'start': 528.77,
#   'duration': 4.491},
#  {'text': 'which would give the corresponding little bit of distance traveled during that little',
#   'start': 533.261,
#   'duration': 4.598},
#  {'text': 'time.', 'start': 537.859, 'duration': 0.321},
#  {'text': "I'll talk through the details of examples like this later in the series,",
#   'start': 539.26,
#   'duration': 3.896},
#  {'text': 'but at a high level many of these types of problems turn out to be equivalent',
#   'start': 543.156,
#   'duration': 4.222},
#  {'text': 'to finding the area under some graph, in much the same way that our circle problem did.',
#   'start': 547.378,
#   'duration': 4.762},
#  {'text': "This happens whenever the quantities you're adding up,",
#   'start': 553.2,
#   'duration': 2.947},
#  {'text': 'the one whose sum approximates the original problem,',
#   'start': 556.147,
#   'duration': 2.891},
#  {'text': 'can be thought of as the areas of many thin rectangles sitting side by side.',
#   'start': 559.038,
#   'duration': 4.202},
#  {'text': 'If finer and finer approximations of the original problem correspond to thinner and',
#   'start': 564.64,
#   'duration': 5.14},
#  {'text': 'thinner rings, then the original problem is equivalent to finding the area under some',
#   'start': 569.78,
#   'duration': 5.326},
#  {'text': 'graph.', 'start': 575.106, 'duration': 0.434},
#  {'text': "Again, this is an idea we'll see in more detail later in the series,",
#   'start': 576.6,
#   'duration': 3.824},
#  {'text': "so don't worry if it's not 100% clear right now.",
#   'start': 580.424,
#   'duration': 2.756},
#  {'text': 'The point now is that you, as the mathematician having just',
#   'start': 583.78,
#   'duration': 3.371},
#  {'text': 'solved a problem by reframing it as the area under a graph,',
#   'start': 587.151,
#   'duration': 3.427},
#  {'text': 'might start thinking about how to find the areas under other graphs.',
#   'start': 590.578,
#   'duration': 3.942},
#  {'text': 'We were lucky in the circle problem that the relevant area turned out to be a triangle,',
#   'start': 595.64,
#   'duration': 4.678},
#  {'text': 'but imagine instead something like a parabola, the graph of x2.',
#   'start': 600.318,
#   'duration': 3.442},
#  {'text': "What's the area underneath that curve, say between",
#   'start': 604.76,
#   'duration': 3.253},
#  {'text': 'the values of x equals 0 and x equals 3?',
#   'start': 608.013,
#   'duration': 2.667},
#  {'text': "Well, it's hard to think about, right?",
#   'start': 612.08,
#   'duration': 2.68},
#  {'text': 'And let me reframe that question in a slightly different way.',
#   'start': 615.22,
#   'duration': 2.8},
#  {'text': "We'll fix that left endpoint in place at 0, and let the right endpoint vary.",
#   'start': 618.02,
#   'duration': 5.04},
#  {'text': 'Are you able to find a function, a of x, that gives',
#   'start': 626.86,
#   'duration': 3.696},
#  {'text': 'you the area under this parabola between 0 and x?',
#   'start': 630.556,
#   'duration': 3.624},
#  {'text': 'A function a of x like this is called an integral of x2.',
#   'start': 635.62,
#   'duration': 3.96},
#  {'text': 'Calculus holds within it the tools to figure out what an integral like this is,',
#   'start': 640.5,
#   'duration': 4.103},
#  {'text': "but right now it's just a mystery function to us.",
#   'start': 644.603,
#   'duration': 2.597},
#  {'text': 'We know it gives the area under the graph of x2 between some fixed left',
#   'start': 647.5,
#   'duration': 3.818},
#  {'text': "point and some variable right point, but we don't know what it is.",
#   'start': 651.318,
#   'duration': 3.602},
#  {'text': 'And again, the reason we care about this kind of question is not just for',
#   'start': 655.66,
#   'duration': 4.189},
#  {'text': "the sake of asking hard geometry questions, it's because many practical",
#   'start': 659.849,
#   'duration': 4.131},
#  {'text': 'problems that can be approximated by adding up a large number of small',
#   'start': 663.98,
#   'duration': 4.074},
#  {'text': 'things can be reframed as a question about an area under a certain graph.',
#   'start': 668.054,
#   'duration': 4.246},
#  {'text': "I'll tell you right now that finding this area, this integral function,",
#   'start': 673.42,
#   'duration': 3.952},
#  {'text': 'is genuinely hard, and whenever you come across a genuinely hard question in math,',
#   'start': 677.372,
#   'duration': 4.62},
#  {'text': 'a good policy is to not try too hard to get at the answer directly,',
#   'start': 681.992,
#   'duration': 3.785},
#  {'text': 'since usually you just end up banging your head against a wall.',
#   'start': 685.777,
#   'duration': 3.563},
#  {'text': 'Instead, play around with the idea, with no particular goal in mind.',
#   'start': 690.08,
#   'duration': 3.7},
#  {'text': 'Spend some time building up familiarity with the interplay between the function',
#   'start': 694.34,
#   'duration': 4.224},
#  {'text': 'defining the graph, in this case x2, and the function giving the area.',
#   'start': 698.564,
#   'duration': 3.796},
#  {'text': "In that playful spirit, if you're lucky, here's something you might notice.",
#   'start': 704.09,
#   'duration': 3.93},
#  {'text': 'When you slightly increase x by some tiny nudge dx, look at the resulting change in area,',
#   'start': 708.58,
#   'duration': 6.199},
#  {'text': "represented with this sliver I'm going to call da for a tiny difference in area.",
#   'start': 714.779,
#   'duration': 5.641},
#  {'text': 'That sliver can be pretty well approximated with a rectangle,',
#   'start': 721.38,
#   'duration': 4.127},
#  {'text': 'one whose height is x2 and whose width is dx.',
#   'start': 725.507,
#   'duration': 3.113},
#  {'text': 'And the smaller the size of that nudge dx, the',
#   'start': 729.66,
#   'duration': 2.568},
#  {'text': 'more that sliver actually looks like a rectangle.',
#   'start': 732.228,
#   'duration': 2.792},
#  {'text': 'This gives us an interesting way to think about how a of x is related to x2.',
#   'start': 736.8,
#   'duration': 4.28},
#  {'text': 'A change to the output of a, this little da, is about equal to x2,',
#   'start': 742.0,
#   'duration': 4.578},
#  {'text': 'where x is whatever input you started at, times dx,',
#   'start': 746.578,
#   'duration': 3.607},
#  {'text': 'the little nudge to the input that caused a to change.',
#   'start': 750.185,
#   'duration': 3.815},
#  {'text': 'Or rearranged, da divided by dx, the ratio of a tiny change in a to the tiny',
#   'start': 754.78,
#   'duration': 5.536},
#  {'text': 'change in x that caused it, is approximately whatever x2 is at that point.',
#   'start': 760.316,
#   'duration': 5.464},
#  {'text': "And that's an approximation that should get better",
#   'start': 766.56,
#   'duration': 2.2},
#  {'text': 'and better for smaller and smaller choices of dx.',
#   'start': 768.76,
#   'duration': 2.2},
#  {'text': "In other words, we don't know what a of x is, that remains a mystery.",
#   'start': 772.1,
#   'duration': 3.54},
#  {'text': 'But we do know a property that this mystery function must have.',
#   'start': 776.08,
#   'duration': 3.42},
#  {'text': 'When you look at two nearby points, for example 3 and 3.001,',
#   'start': 780.16,
#   'duration': 4.812},
#  {'text': 'consider the change to the output of a between those two points,',
#   'start': 784.972,
#   'duration': 5.213},
#  {'text': 'the difference between the mystery function evaluated at 3.001 and 3.001.',
#   'start': 790.185,
#   'duration': 5.935},
#  {'text': 'That change, divided by the difference in the input values, which in this case is 0.001,',
#   'start': 796.12,
#   'duration': 5.956},
#  {'text': 'should be about equal to the value of x2 for the starting input, in this case 3 squared.',
#   'start': 802.076,
#   'duration': 6.024},
#  {'text': 'And this relationship between tiny changes to the mystery function',
#   'start': 810.2,
#   'duration': 4.216},
#  {'text': 'and the values of x2 itself is true at all inputs, not just 3.',
#   'start': 814.416,
#   'duration': 4.024},
#  {'text': "That doesn't immediately tell us how to find a of x,",
#   'start': 819.42,
#   'duration': 2.553},
#  {'text': 'but it provides a very strong clue that we can work with.',
#   'start': 821.973,
#   'duration': 2.847},
#  {'text': "And there's nothing special about the graph x2 here.",
#   'start': 826.26,
#   'duration': 2.48},
#  {'text': 'Any function defined as the area under some graph has this property,',
#   'start': 829.28,
#   'duration': 4.367},
#  {'text': 'that da divided by dx, a slight nudge to the output of a divided by a slight',
#   'start': 833.647,
#   'duration': 4.945},
#  {'text': 'nudge to the input that caused it, is about equal to the height of the graph at',
#   'start': 838.592,
#   'duration': 5.137},
#  {'text': 'that point.', 'start': 843.729, 'duration': 0.771},
#  {'text': "Again, that's an approximation that gets better and better for smaller choices of dx.",
#   'start': 846.2,
#   'duration': 4.16},
#  {'text': "And here, we're stumbling into another big idea from calculus, derivatives.",
#   'start': 851.64,
#   'duration': 4.4},
#  {'text': 'This ratio da divided by dx is called the derivative of a, or more technically,',
#   'start': 857.1,
#   'duration': 5.007},
#  {'text': 'the derivative is whatever this ratio approaches as dx gets smaller and smaller.',
#   'start': 862.107,
#   'duration': 5.133},
#  {'text': "I'll dive much more deeply into the idea of a derivative in the next video,",
#   'start': 868.18,
#   'duration': 3.858},
#  {'text': "but loosely speaking it's a measure of how sensitive a function is to small changes in",
#   'start': 872.038,
#   'duration': 4.476},
#  {'text': 'its input.', 'start': 876.514, 'duration': 0.566},
#  {'text': "You'll see as the series goes on that there are many ways you can visualize a derivative,",
#   'start': 877.94,
#   'duration': 4.234},
#  {'text': "depending on what function you're looking at and how you think",
#   'start': 882.174,
#   'duration': 2.996},
#  {'text': 'about tiny nudges to its output.',
#   'start': 885.17,
#   'duration': 1.57},
#  {'text': 'We care about derivatives because they help us solve problems,',
#   'start': 888.6,
#   'duration': 3.554},
#  {'text': "and in our little exploration here, we already have a glimpse of one way they're used.",
#   'start': 892.154,
#   'duration': 4.986},
#  {'text': 'They are the key to solving integral questions,',
#   'start': 897.84,
#   'duration': 2.597},
#  {'text': 'problems that require finding the area under a curve.',
#   'start': 900.437,
#   'duration': 2.983},
#  {'text': 'Once you gain enough familiarity with computing derivatives,',
#   'start': 904.36,
#   'duration': 3.31},
#  {'text': "you'll be able to look at a situation like this one where you don't know what a function",
#   'start': 907.67,
#   'duration': 4.911},
#  {'text': 'is, but you do know that its derivative should be x2,',
#   'start': 912.581,
#   'duration': 2.979},
#  {'text': 'and from that reverse engineer what the function must be.',
#   'start': 915.56,
#   'duration': 3.2},
#  {'text': 'This back and forth between integrals and derivatives,',
#   'start': 920.7,
#   'duration': 3.126},
#  {'text': 'where the derivative of a function for the area under a graph gives you',
#   'start': 923.826,
#   'duration': 4.168},
#  {'text': 'back the function defining the graph itself, is called the fundamental',
#   'start': 927.994,
#   'duration': 4.11},
#  {'text': 'theorem of calculus.', 'start': 932.104, 'duration': 1.216},
#  {'text': 'It ties together the two big ideas of integrals and derivatives,',
#   'start': 934.22,
#   'duration': 4.53},
#  {'text': 'and shows how each one is an inverse of the other.',
#   'start': 938.75,
#   'duration': 3.61},
#  {'text': 'All of this is only a high-level view, just a peek',
#   'start': 944.8,
#   'duration': 2.505},
#  {'text': 'at some of the core ideas that emerge in calculus.',
#   'start': 947.305,
#   'duration': 2.555},
#  {'text': 'And what follows in this series are the details, for derivatives and integrals and more.',
#   'start': 950.5,
#   'duration': 3.92},
#  {'text': 'At all points, I want you to feel that you could have invented calculus yourself,',
#   'start': 954.98,
#   'duration': 4.126},
#  {'text': 'that if you drew the right pictures and played with each idea in just the right way,',
#   'start': 959.106,
#   'duration': 4.329},
#  {'text': 'these formulas and rules and constructs that are presented could have just',
#   'start': 963.435,
#   'duration': 3.82},
#  {'text': 'as easily popped out naturally from your own explorations.',
#   'start': 967.255,
#   'duration': 3.005},
#  {'text': 'And before you go, it would feel wrong not to give the people who supported this',
#   'start': 972.38,
#   'duration': 3.925},
#  {'text': 'series on Patreon a well-deserved thanks, both for their financial backing as',
#   'start': 976.305,
#   'duration': 3.826},
#  {'text': 'well as for the suggestions they gave while the series was being developed.',
#   'start': 980.131,
#   'duration': 3.729},
#  {'text': 'You see, supporters got early access to the videos as I made them,',
#   'start': 984.7,
#   'duration': 3.188},
#  {'text': "and they'll continue to get early access for future essence-of type series.",
#   'start': 987.888,
#   'duration': 3.672},
#  {'text': 'And as a thanks to the community, I keep ads off of new videos for their first month.',
#   'start': 992.14,
#   'duration': 4.1},
#  {'text': "I'm still astounded that I can spend time working on videos like these,",
#   'start': 997.02,
#   'duration': 3.442},
#  {'text': 'and in a very direct way, you are the one to thank for that.',
#   'start': 1000.462,
#   'duration': 2.958}]

# %%
transcript_joined="".join(line['text']for line in transcript)

# %%
transcript_joined
# Out:
# "Hey everyone, Grant here.This is the first video in a series on the essence of calculus,and I'll be publishing the following videos once per day for the next 10 days.The goal here, as the name suggests, is to really getthe heart of the subject out in one binge-watchable set.But with a topic that's as broad as calculus, there's a lot of things that can mean,so here's what I have in mind specifically.Calculus has a lot of rules and formulas whichare often presented as things to be memorized.Lots of derivative formulas, the product rule, the chain rule,implicit differentiation, the fact that integrals and derivatives are opposite,Taylor series, just a lot of things like that.And my goal is for you to come away feeling likeyou could have invented calculus yourself.That is, cover all those core ideas, but in a way that makes clear where theyactually come from, and what they really mean, using an all-around visual approach.Inventing math is no joke, and there is a difference between beingtold why something's true, and actually generating it from scratch.But at all points, I want you to think to yourself, if you were an early mathematician,pondering these ideas and drawing out the right diagrams,does it feel reasonable that you could have stumbled across these truths yourself?In this initial video, I want to show how you might stumble into the core ideas ofcalculus by thinking very deeply about one specific bit of geometry,the area of a circle.Maybe you know that this is pi times its radius squared, but why?Is there a nice way to think about where this formula comes from?Well, contemplating this problem and leaving yourself open to exploring theinteresting thoughts that come about can actually lead you to a glimpse of threebig ideas in calculus, integrals, derivatives, and the fact that they're opposites.But the story starts more simply, just you and a circle, let's say with radius 3.You're trying to figure out its area, and after going through a lot ofpaper trying different ways to chop up and rearrange the pieces of that area,many of which might lead to their own interesting observations,maybe you try out the idea of slicing up the circle into many concentric rings.This should seem promising because it respects the symmetry of the circle,and math has a tendency to reward you when you respect its symmetries.Let's take one of those rings, which has some inner radius r that's between 0 and 3.If we can find a nice expression for the area of each ring like this one,and if we have a nice way to add them all up,it might lead us to an understanding of the full circle's area.Maybe you start by imagining straightening out this ring.And you could try thinking through exactly what this new shape is and what itsarea should be, but for simplicity, let's just approximate it as a rectangle.The width of that rectangle is the circumference of the original ring,which is 2 pi times r, right?I mean, that's essentially the definition of pi.And its thickness?Well, that depends on how finely you chopped up the circle in the first place,which was kind of arbitrary.In the spirit of using what will come to be standard calculus notation,let's call that thickness dr for a tiny difference in the radius from one ring tothe next.Maybe you think of it as something like 0.1.So approximating this unwrapped ring as a thin rectangle,its area is 2 pi times r, the radius, times dr, the little thickness.And even though that's not perfect, for smaller and smaller choices of dr,this is actually going to be a better and better approximation for that area,since the top and the bottom sides of this shape are going to get closer and closer tobeing exactly the same length.So let's just move forward with this approximation,keeping in the back of our minds that it's slightly wrong,but it's going to become more accurate for smaller and smaller choices of dr.That is, if we slice up the circle into thinner and thinner rings.So just to sum up where we are, you've broken up the area  ...

# %%
# !pip install git+https://github.com/babthamotharan/rpunct.git@patch-2
# Out:
# Collecting git+https://github.com/babthamotharan/rpunct.git@patch-2
#   Cloning https://github.com/babthamotharan/rpunct.git (to revision patch-2) to /tmp/pip-req-build-iblg98xq
#   Running command git clone --filter=blob:none --quiet https://github.com/babthamotharan/rpunct.git /tmp/pip-req-build-iblg98xq
#   Running command git checkout -b patch-2 --track origin/patch-2
#   Switched to a new branch 'patch-2'
#   Branch 'patch-2' set up to track remote branch 'patch-2' from 'origin'.
#   Resolved https://github.com/babthamotharan/rpunct.git to commit a87b93410ca782657abb4e34df9159e6e47ac9ec
#   Preparing metadata (setup.py) ... done
# Collecting langdetect>=1.0.9 (from rpunct==1.0.2)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 12.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.2.4 in /usr/local/lib/python3.11/dist-packages (from rpunct==1.0.2) (2.2.2)
# Collecting simpletransformers>=0.61.4 (from rpunct==1.0.2)
#   Downloading simpletransformers-0.70.1-py3-none-any.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from rpunct==1.0.2) (1.17.0)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from rpunct==1.0.2) (2.6.0+cu124)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.4->rpunct==1.0.2) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.4->rpunct==1.0.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.4->rpunct==1.0.2) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.4->rpunct==1.0.2) (2025.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from simpletransformers>=0.61.4->rpunct==1.0.2) (2.32.3)
# Requirement already satisfied: tqdm>=4.47.0 in /usr/local/lib/python3.11/dist-packages (from simpletransformers>=0.61.4->rpunct==1.0.2) (4.67.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from simpletransformers>=0.61.4->rpunct==1.0.2) (2024.11.6)
# Requirement already satisfied: transformers>=4.31.0 in /usr/local/lib/python3.11/dist-packages (from simpletransformers>=0.61.4->rpunct==1.0.2) (4.49.0)
# Collecting datasets (from simpletransformers>=0.61.4->rpunct==1.0.2)
#   Downloading datasets-3.4.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from simpletransformers>=0.61.4->rpunct==1.0.2) (1.14.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from simpletransformers>=0.61.4->rpunct==1.0.2) (1.6.1)
# Collecting seqeval (from simpletransformers>=0.61.4->rpunct==1.0.2)
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.11/dist-packages (from simpletransformers>=0.61.4->rpunct==1.0.2) (2.18.0)
# Collecting tensorboardx (from simpletransformers>=0.61.4->rpunct==1.0.2)
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.11/dist-packages (from simpletransformers>=0.61.4->rpunct==1.0.2) (0.21.1)
# Requirement already satisfied: wandb>=0.10.32 in /usr/local/lib/python3.11/dist-packages (from simpletransformers>=0.61.4->rpunct==1.0.2) (0.19.8)
# Collecting streamlit (from simpletransformers>=0.61.4->rpunct==1.0.2)
#   Downloading streamlit-1.43.2-py2.py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from simpletransformers>=0.61.4->rpunct==1.0.2) (0.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->rpunct==1.0.2) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->rpunct==1.0.2) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->rpunct==1.0.2) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->rpunct==1.0.2) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->rpunct==1.0.2) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.1->rpunct==1.0.2)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.1->rpunct==1.0.2)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.1->rpunct==1.0.2)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.1->rpunct==1.0.2)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.1->rpunct==1.0.2)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.1->rpunct==1.0.2)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.1->rpunct==1.0.2)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.1->rpunct==1.0.2)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.1->rpunct==1.0.2)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->rpunct==1.0.2) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->rpunct==1.0.2) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->rpunct==1.0.2) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.1->rpunct==1.0.2)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->rpunct==1.0.2) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.1->rpunct==1.0.2) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.1->rpunct==1.0.2) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.31.0->simpletransformers>=0.61.4->rpunct==1.0.2) (0.29.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.31.0->simpletransformers>=0.61.4->rpunct==1.0.2) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.31.0->simpletransformers>=0.61.4->rpunct==1.0.2) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.31.0->simpletransformers>=0.61.4->rpunct==1.0.2) (0.5.3)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.10.32->simpletransformers>=0.61.4->rpunct==1.0.2) (8.1.8)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.10.32->simpletransformers>=0.61.4->rpunct==1.0.2) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.10.32->simpletransformers>=0.61.4->rpunct==1.0.2) (3.1.44)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb>=0.10.32->simpletransformers>=0.61.4->rpunct==1.0.2) (4.3.6)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.10.32->simpletransformers>=0.61.4->rpunct==1.0.2) (5.29.3)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.10.32->simpletransformers>=0.61.4->rpunct==1.0.2) (5.9.5)
# Requirement already satisfied: pydantic<3,>=2.6 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.10.32->simpletransformers>=0.61.4->rpunct==1.0.2) (2.10.6)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.10.32->simpletransformers>=0.61.4->rpunct==1.0.2) (2.23.1)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb>=0.10.32->simpletransformers>=0.61.4->rpunct==1.0.2) (1.3.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from wandb>=0.10.32->simpletransformers>=0.61.4->rpunct==1.0.2) (75.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->simpletransformers>=0.61.4->rpunct==1.0.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->simpletransformers>=0.61.4->rpunct==1.0.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->simpletransformers>=0.61.4->rpunct==1.0.2) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->simpletransformers>=0.61.4->rpunct==1.0.2) (2025.1.31)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets->simpletransformers>=0.61.4->rpunct==1.0.2) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->simpletransformers>=0.61.4->rpunct==1.0.2)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting xxhash (from datasets->simpletransformers>=0.61.4->rpunct==1.0.2)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets->simpletransformers>=0.61.4->rpunct==1.0.2)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec (from torch>=1.8.1->rpunct==1.0.2)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets->simpletransformers>=0.61.4->rpunct==1.0.2) (3.11.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.1->rpunct==1.0.2) (3.0.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->simpletransformers>=0.61.4->rpunct==1.0.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->simpletransformers>=0.61.4->rpunct==1.0.2) (3.6.0)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->simpletransformers>=0.61.4->rpunct==1.0.2) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->simpletransformers>=0.61.4->rpunct==1.0.2) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->simpletransformers>=0.61.4->rpunct==1.0.2) (5.5.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->simpletransformers>=0.61.4->rpunct==1.0.2) (11.1.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->simpletransformers>=0.61.4->rpunct==1.0.2) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from streamlit->simpletransformers>=0.61.4->rpunct==1.0.2) (0.10.2)
# Collecting watchdog<7,>=2.1.5 (from streamlit->simpletransformers>=0.61.4->rpunct==1.0.2)
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.3 MB/s eta 0:00:00
# Collecting pydeck<1,>=0.8.0b4 (from streamlit->simpletransformers>=0.61.4->rpunct==1.0.2)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.11/dist-packages (from streamlit->simpletransformers>=0.61.4->rpunct==1.0.2) (6.4.2)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard->simpletransformers>=0.61.4->rpunct==1.0.2) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard->simpletransformers>=0.61.4->rpunct==1.0.2) (1.71.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard->simpletransformers>=0.61.4->rpunct==1.0.2) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->simpletransformers>=0.61.4->rpunct==1.0.2) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard->simpletransformers>=0.61.4->rpunct==1.0.2) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit->simpletransformers>=0.61.4->rpunct==1.0.2) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit->simpletransformers>=0.61.4->rpunct==1.0.2) (1.31.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->simpletransformers>=0.61.4->rpunct==1.0.2) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->simpletransformers>=0.61.4->rpunct==1.0.2) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->simpletransformers>=0.61.4->rpunct==1.0.2) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->simpletransformers>=0.61.4->rpunct==1.0.2) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->simpletransformers>=0.61.4->rpunct==1.0.2) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->simpletransformers>=0.61.4->rpunct==1.0.2) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->simpletransformers>=0.61.4->rpunct==1.0.2) (1.18.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers>=0.61.4->rpunct==1.0.2) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.6->wandb>=0.10.32->simpletransformers>=0.61.4->rpunct==1.0.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.6->wandb>=0.10.32->simpletransformers>=0.61.4->rpunct==1.0.2) (2.27.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers>=0.61.4->rpunct==1.0.2) (5.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers>=0.61.4->rpunct==1.0.2) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers>=0.61.4->rpunct==1.0.2) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers>=0.61.4->rpunct==1.0.2) (0.23.1)
# Downloading simpletransformers-0.70.1-py3-none-any.whl (316 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.3/316.3 kB 21.8 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 96.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 86.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 88.7 MB/s eta 0:00:00
# Downloading datasets-3.4.1-py3-none-any.whl (487 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.4/487.4 kB 35.6 MB/s eta 0:00:00
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 17.7 MB/s eta 0:00:00
# Downloading streamlit-1.43.2-py2.py3-none-any.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 116.0 MB/s eta 0:00:00
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 10.0 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.6 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 14.7 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 106.9 MB/s eta 0:00:00
# Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 8.3 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 17.9 MB/s eta 0:00:00
# Building wheels for collected packages: rpunct, langdetect, seqeval
#   Building wheel for rpunct (setup.py) ... done
#   Created wheel for rpunct: filename=rpunct-1.0.2-py3-none-any.whl size=5889 sha256=2ee9815566e81b50352943e7ff0d4f3786f21f61be2ed64848538802655e8694
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ut75iwd0/wheels/be/5b/6a/bc4b174e97ac0584ce55ca312be4310c1e76ed17db89e8dc32
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993222 sha256=887c60b2809ca630dfa97052a2b5863acfbfa478914c844c8a686eba7f303595
#   Stored in directory: /root/.cache/pip/wheels/0a/f2/b2/e5ca405801e05eb7c8ed5b3b4bcf1fcabcd6272c167640072e
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16161 sha256=78f33d79cd4a263cf1a283df33b4c1b4f3e508579a439a4e93366e7d3a1ab65b
#   Stored in directory: /root/.cache/pip/wheels/bc/92/f0/243288f899c2eacdfa8c5f9aede4c71a9bad0ee26a01dc5ead
# Successfully built rpunct langdetect seqeval
# Installing collected packages: xxhash, watchdog, tensorboardx, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, langdetect, fsspec, dill, pydeck, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, seqeval, nvidia-cusolver-cu12, datasets, streamlit, simpletransformers, rpunct
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.12.0 which is incompatible.
# Successfully installed datasets-3.4.1 dill-0.3.8 fsspec-2024.12.0 langdetect-1.0.9 multiprocess-0.70.16 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pydeck-0.9.1 rpunct-1.0.2 seqeval-1.2.2 simpletransformers-0.70.1 streamlit-1.43.2 tensorboardx-2.6.2.2 watchdog-6.0.0 xxhash-3.5.0

# %%
from rpunct import RestorePuncts
rpunct = RestorePuncts()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.25k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/436M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/530 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
results=rpunct.punctuate(transcript_joined)
# Out:
# /usr/local/lib/python3.11/dist-packages/simpletransformers/ner/ner_model.py:1643: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():

# %%
print(results)
# Out:
# Hey Everyone, Grant here.This is the first video in a series on the essence of calculus,and I'll be publishing the following videos once per day for the next 10 days.The Goal here, as the name suggests,, is to really getthe heart of the subject out in one binge-watchable set.But With a topic that's as broad as calculus,, there's a lot of things that can mean,so here's what I have in mind specifically.Calculus has a lot of rules and formulas, whichare often presented as things to be memorized.Lots of derivative formulas, the product rule, the chain rule,implicit differentiation, the fact that integrals and derivatives are opposite,Taylor series, just a lot of things like that.And My goal is for you to come away feeling likeyou could have invented calculus yourself.That is, cover all those core ideas, but in a way that makes clear where theyactually come from, and what they really mean, using an all-around visual approach.Inventing Math is no joke, and there is a difference between beingtold why something's true, and actually generating it from scratch.But At all points, I Want you to think to yourself, if you were an early mathematician,pondering these ideas and drawing out the right diagrams,does, it feel reasonable that you could have stumbled across these truths yourself?In This initial video, I Want to show how you might stumble into the core ideas ofcalculus by thinking very deeply about one specific bit of geometry,the area of a circle.Maybe You know that this is Pi times its radius squared, but why?Is There a nice way to think about where this formula comes from?Well, contemplating this problem and leaving yourself open to exploring theinteresting thoughts that come about can actually lead you to a glimpse of threebig ideas in calculus, integrals, derivatives, and the fact that they're opposites.But The story starts more simply, just you and a circle, let's say with radius 3.You're trying to figure out its area, and after going through a lot ofpaper trying different ways to chop up and rearrange the pieces of that area,many of which might lead to their own interesting observations,maybe, you try out the idea of slicing up the circle into many concentric rings.This. should seem promising because it respects the symmetry of the circle,and math has a tendency to reward you when you respect its symmetries.Let's. take one of those rings, which has some inner radius r that's between 0 and 3.If We can find a nice expression for the area of each ring like this one,and, if we have a nice way to add them all up,it might lead us to an understanding of the full circle's area.Maybe. You start by imagining straightening out this ring.And You could try thinking through exactly what this new shape is and what itsarea should be, but for simplicity,, let's just approximate it as a rectangle.The. Width of that rectangle is the circumference of the original ring,which is 2 Pi times r, right?I Mean, that's essentially the definition of Pi.and its thickness?Well, that depends on how finely you chopped up the circle in the first place,which was kind of arbitrary.In The spirit of using what will come to be standard calculus notation,let's, call that thickness dr. for a tiny difference in the radius from one ring tothe next.Maybe. You think of it as something like 0.1.So Approximating this unwrapped ring as a thin rectangle,its area is 2 Pi times r, the radius, times Dr,. the little thickness.And Even though that's not perfect,, for smaller and smaller choices of Dr,this. is actually going to be a better and better approximation for that area,since the top and the bottom sides of this shape are going to get closer and closer tobeing exactly the same length.So. Let's just move forward with this approximation,keeping in the back of our minds that it's slightly wrong,but, it's going to become more accurate for smaller and smaller choices of Dr.that. is, if we slice up the circle into thinner and thinner rings.So Just to sum up where we are,, you've ...

# %%
# !pip install -q -U google-generativeai

# %%
import pathlib
import textwrap
import os
import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
    text = text.replace("•", "  *")
    return Markdown(textwrap.indent(text, "> ", predicate=lambda _: True))

# %%
#from google.colab import userdata

# %%
# Import the Python SDK
import google.generativeai as genai
# Used to securely store your API key
from google.colab import userdata

GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)

# %%
#model = genai.GenerativeModel('gemini-pro')

# %%
model = genai.GenerativeModel("gemini-1.5-flash")

# %%
response = model.generate_content("Summarize for me" + transcript_joined)
print(response.text)
# Out:
# This video series aims to explain the core concepts of calculus intuitively, focusing on understanding rather than memorization.  The first video uses the area of a circle as a starting point.  By approximating the circle's area using concentric rings and treating each ring as a rectangle, the concept of integration emerges as summing the areas of these rectangles.  As the width of the rings (dr) approaches zero, the sum of the rectangular areas approximates the area under the curve 2πr, which is a triangle, yielding the familiar formula for the area of a circle (πr²).
#
# This process introduces the idea of integrals and their connection to the area under a curve.  The video then explores the relationship between a function (like x²) and the area under its curve.  By considering a tiny change in the area (da) resulting from a small change in x (dx), the concept of a derivative (da/dx) is introduced as a measure of the function's sensitivity to small changes in its input.  The video highlights that the derivative of the function representing the area under a curve is the original function itself, illustrating the fundamental theorem of calculus.  The series promises to further explore these concepts and other core ideas of calculus in a visually intuitive way.
